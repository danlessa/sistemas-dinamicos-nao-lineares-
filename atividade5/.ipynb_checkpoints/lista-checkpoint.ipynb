# %% [markdown]
# # Atividade 5 de sistemas dinâmicos
#
# *Danilo Lessa Bernardineli (danilo.bernardineli@usp.br)*

# %%
# %load_ext autotime

# %%
# Dependences
from scipy.integrate import solve_ivp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
# Out:
# time: 1.05 s

# %% [markdown]
# ## Exercício 1 - atrator de Rossler
#
# ### Fig 9.7

# %%
def rossler(t, X, a, b, c):
    (x, y, z) = X
    dx = -(y + z)
    dy = x + a * y
    dz = b + z * (x - c)
    return (dx, dy, dz)
# Out:
# time: 1.74 ms

# %%
(a, b) = (0.1, 0.1)
T = (0, 1000)
X_0 = (0, 0, 0)
c_list = [4, 6, 8.5, 8.7, 9.0, 12, 12.8, 13.0, 18.0]
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))

for i, c in enumerate(c_list):
    f = solve_ivp(rossler, T, X_0, args=(a, b, c))
    (x, y, z) = f.y[:, 1000:]
    axes.ravel()[i].plot(x, y, '.-', linewidth=0.05, markersize=0.01, label=f"c: {c :.2f}")
plt.legend()
plt.show()
# Out:
# time: 13.6 s

# %% [markdown]
# ### Fig 9.8

# %%
(a, b) = (0.1, 0.1)
T = (10000, 10001)

N = 100
X_0 = np.random.rand(N, 3) * 50
c_list = np.linspace(1, 46, 100)

bifurcation = {}
for c in c_list:
    solve_rossler = lambda x_0: solve_ivp(rossler, T, x_0, args=(a, b, c), method='RK23')
    F = np.apply_along_axis(solve_rossler, 1, X_0)
    X = [f.y[0][-1] for f in F]
    bifurcation[c] = X
# Out:
# time: 41.8 s

# %%
x, y = zip(*bifurcation.items())
plt.figure(figsize=(12, 6))
plt.plot(x, y, '.-', color='k', linewidth=0.2, markersize=1.0)
plt.ylabel("x")
plt.xlabel("c")
plt.show()
# Out:
# time: 669 ms

# %% [markdown]
# ### Exercicio 2

# %%
def chua(t, X, c, g):
    (x, y, z) = X
    (c_1, c_2, c_3) = c
    dx = c_1 * (y - x - g(x))
    dy = c_2 * (x - y + z)
    dz = -1.0 * c_3 * y
    return (dx, dy, dz)

(m_0, m_1) = (-8 / 7, -5 / 7)
T = (11000, 12000)
c = [15.6, 1.0, 25.58]
c_list = [50, 35, 33.8, 33.6, 33, 25.8]
g = lambda x: m_1 * x + m_1 - m_0 if x < -1.0 else (m_0 * x if x < 1.0 else m_1 * x + m_0 - m_1)
X_0 = (3 * np.random.rand(3) - 1.5)
args = (c, g)

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 12))
for i, c_3 in enumerate(c_list):
    c[-1] = c_3
    f = solve_ivp(chua, T, X_0, args=(c, g))
    (x, y, z) = f.y[:, 1000:]
    axes.ravel()[i].plot(x, y, '.-', linewidth=0.05, markersize=0.01, label=f"c: {c_3 :.2f}")
    axes.ravel()[i].legend()
plt.show()
# Out:
# time: 8.4 s

# %% [markdown]
# ### Exercicio 3

# %% [markdown]
# #### $\delta=1.1$

# %%
from numpy import conj

def three_wave(t, A, nu, delta):
    (A_1, A_2, A_3) = A
    dA_1 = 1 * A_1 + A_2 * A_3
    dA_2 = nu * A_2 - A_1 * conj(A_3)
    dA_3 = nu * A_3 - A_1 * conj(A_2) + 1j * delta * A_3
    return (dA_1, dA_2, dA_3)

T = (1e5, 1e5 + 1000)
nu = -14.5
delta = 1.1
args = (nu, delta)
X_0 = np.random.rand(3).astype(np.cfloat)
f = solve_ivp(three_wave, T, X_0,
              args=args, method='RK45',
              dense_output=True)

# Prepare
t = f.t
a = f.y
a_1 = np.abs(a[0])
a_2 = np.abs(a[1])

# Plot
plt.figure(figsize=(15, 5))
plt.plot(a_1, a_2, '.-', linewidth=0.05, markersize=0.1)
plt.show()
# Out:
# time: 4.64 s

# %% [markdown]
# #### $\delta = 2.2$

# %%
def three_wave(t, A, nu, delta):
    (A_1, A_2, A_3) = A
    dA_1 = 1 * A_1 + A_2 * A_3
    dA_2 = nu * A_2 - A_1 * conj(A_3)
    dA_3 = nu * A_3 - A_1 * conj(A_2) + 1j * delta * A_3
    return (dA_1, dA_2, dA_3)

T = (1e5, 1e5 + 1000)
nu = -14.5
delta = 2.2
args = (nu, delta)
X_0 = np.random.rand(3).astype(np.cfloat)
f = solve_ivp(three_wave, T, X_0,
              args=args, method='RK45',
              dense_output=True)

# Prepare
t = f.t
a = f.y
a_1 = np.abs(a[0])
a_2 = np.abs(a[1])

# Plot
plt.figure(figsize=(15, 5))
plt.plot(a_1, a_2, '.-', linewidth=0.05, markersize=0.1)
plt.show()
# Out:
# time: 4.71 s

# %% [markdown]
# ### Exercicio 4 - modelo de neurônio

# %%
def I(t, I_0, t_0, dt):
    """
    Current impulse function
    """
    if t > t_0:
        if t < t_0 + dt:
            return I_0
    return 0


def neuron(t, X, a, b, c, d, r, s, I_0, t_0, dt, x_1):
    """
    Neuron model
    """
    (x, y, z) = X
    I_t = I(t, I_0, t_0, dt)
    dx = y - a * x ** 3 + b * x ** 2 + I_t - z
    dy = c - d * x ** 2 - y
    dz = r * (s * (x - x_1) - z)
    return (dx, dy, dz)

# Parameters
T = (0, 3000)
N = 10000
(x_1, y_1, z_1) = (-1.6, -11, 2.2)
(a, b, c, d) = (1, 3, 1, 5)
(r, s) = (0.001, 4.0)
(I_0, t_0, dt) = (2.0, 100, 1500)

# Setup
t_eval = np.linspace(T[0], T[1], N)
neuron_args = (a, b, c, d, r, s, I_0, t_0, dt, x_1)
neuron_X0 = (x_1, y_1, z_1)

# Solve
f = solve_ivp(neuron, T, neuron_X0,
              args=neuron_args)

# Prepare
t = f.t
(x, y, z) = f.y
x_I = np.linspace(t_0, t_0 + dt, 5)
y_I = [I_0] * len(x_I)

# Plot visualization
plt.figure(figsize=(15, 5))
plt.title("Neuron response")
plt.plot(t, x, '.-', linewidth=0.1, markersize=0.2, label='x(t)')
plt.xlabel("t")
plt.ylabel("x(t)")
plt.fill_between(x_I, 0, y_I, color='C1', alpha=0.1, label='I(t)')
plt.axvline(t_0, color='C1', linestyle='--', linewidth=0.5)
plt.axvline(t_0 + dt, color='C1', linestyle='--', linewidth=0.5)
plt.axhline(0, linestyle='--', linewidth=0.5, color='k')
plt.legend()
plt.fill
plt.show()
# Out:
# time: 4.47 s

# %% [markdown]
# ### Exercicio 5 - SEIR

# %%
def SEIR(t, X, beta, omega, gamma):
    (S, E, I, R) = X
    N = S + E + I + R
    new_exposed = beta * S * I / N
    new_infected = omega * E
    new_recovered = gamma * I
    dS = -1 * new_exposed
    dE = new_exposed - new_infected
    dI = new_infected - new_recovered
    dR = new_recovered
    return (dS, dE, dI, dR)

SEIR_T = (0, 150)
(beta_0, k, T_e, T_i) = (0.1, 10.0, 7.0, 10.25)
N_0 = 1e7

(S_0, E_0, I_0, R_0) = (N_0 - 1, 1, 0, 0)
SEIR_X0 = (S_0, E_0, I_0, R_0)
(beta, omega, gamma) = (beta_0 * k, 1 / T_e, 1 / T_i)
SEIR_args = (beta, omega, gamma)

f = solve_ivp(SEIR, SEIR_T, SEIR_X0,
              args=SEIR_args)

t = f.t
(s, e, i, r) = f.y
n = s + e + i + r
plt.figure(figsize=(15, 5))
plt.title("SEIR model")
plt.plot(t, s / n, label='susceptible')
plt.plot(t, e / n, label='exposed')
plt.plot(t, i / n, label='infective')
plt.plot(t, r / n, label='recovered')
plt.ylabel("Fraction of population")
plt.xlabel("Day")
plt.legend()
plt.show()
# Out:
# time: 342 ms
